# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load and clean the data.
bestsellers_df = pd.read_csv('Resources/cleaned_best_seller_code.csv')

# Drop extra column.
bestsellers_df.drop(['Unnamed: 0'], axis=1).head()
# Out:
#   published_date      book_type  rank                    title  \
# 0     2010-01-03  chapter_books     1         WITCH AND WIZARD
# 1     2010-01-03  chapter_books     2         THE HUNGER GAMES
# 2     2010-01-03  chapter_books     3            CATCHING FIRE
# 3     2010-01-03  chapter_books     4  THE MAGICIAN’S ELEPHANT
# 4     2010-01-03  chapter_books     5                   FALLEN
#
#                                      author  \
# 0  James Patterson and Gabrielle Charbonnet
# 1                           Suzanne Collins
# 2                           Suzanne Collins
# 3                            Kate DiCamillo
# 4                               Lauren Kate
#
#                                          description  price  weeks_on_list
# 0  One of each, brother and sister, flex their ne...  17.99              1
# 1  In a dystopian future, a girl fights for survi...  17.99             67
# 2     The protagonist of "The Hunger Games" returns.  17.99             16
# 3  An orphan in search of his sister follows a fo...  16.99             15
# 4  Thwarted love among misfits at a Savannah, Ga....  17.99              2

# %%
# Columns
bestsellers_df.columns
# Out:
# Index(['Unnamed: 0', 'published_date', 'book_type', 'rank', 'title', 'author',
#        'description', 'price', 'weeks_on_list'],
#       dtype='object')

# %%
# Split the Data into Training and Testing.
# Create our features
X = pd.get_dummies(bestsellers_df, columns=['published_date', 'rank', 'title', 'author',
       'description', 'price', 'weeks_on_list']).drop('book_type', axis=1)

# Create our target
y = bestsellers_df['book_type']

# %%
X.describe()
# Out:
#          Unnamed: 0  published_date_2010-01-03  published_date_2010-01-10  \
# count  51997.000000               51997.000000               51997.000000
# mean   28655.160971                   0.001327                   0.001346
# std    17621.342383                   0.036404                   0.036667
# min        0.000000                   0.000000                   0.000000
# 25%    13080.000000                   0.000000                   0.000000
# 50%    27990.000000                   0.000000                   0.000000
# 75%    43600.000000                   0.000000                   0.000000
# max    61424.000000                   1.000000                   1.000000
#
#        published_date_2010-01-17  published_date_2010-01-24  \
# count               51997.000000               51997.000000
# mean                    0.001346                   0.001346
# std                     0.036667                   0.036667
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                     1.000000                   1.000000
#
#        published_date_2010-01-31  published_date_2010-02-07  \
# count               51997.000000               51997.000000
# mean                    0.001346                   0.001346
# std                     0.036667                   0.036667
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                     1.000000                   1.000000
#
#        published_date_2010-02-14  published_date_2010-02-21  \
# count               51997.000000               51997.000000
# mean                    0.001346                   0.001346
# std                     0.036667                   0.036667
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                     1.000000                   1.000000
#
#        published_date_2010-02-28  ...  weeks_on_list_598  weeks_on_list_599  \
# count               51997.000000  ...       51997.000000       51997.000000
# mean                    0.001346  ...           0.000019           0.000019
# std                     0.036667  ...           0.004385           0.004385
# min                     0.000000  ...           0.000000           0.000000
# 25%                     0.000000  ...           0.000000           0.000000
# 50%                     0.000000  ...           0.000000           0.000000
# 75%                     0.000000  ...           0.000000           0.000000
# max                     1.000000  ...           1.000000           1.000000
#
#        weeks_on_list_600  weeks_on_list_601  weeks_on_list_602  \
# count       51997.000000       51997.000000       51997.000000
# mean            0.000019           0.000019           0.000019
# std             0.004385           0.004385           0.004385
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        weeks_on_list_603  weeks_on_list_604  weeks_on_list_605  \
# count       51997.000000       51997.000000       51997.000000
# mean            0.000019           0.000019           0.000019
# std             0.004385           0.004385           0.004385
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        weeks_on_list_606  weeks_on_list_607
# count       51997.000000       51997.000000
# mean            0.000019           0.000019
# std             0.004385           0.004385
# min             0.000000           0.000000
# 25%             0.000000           0.000000
# 50%             0.000000           0.000000
# 75%             0.000000           0.000000
# max             1.000000           1.000000
#
# [8 rows x 18505 columns]

# %%
# Checkout the balance of our taget values
y.value_counts()
# Out:
# hardcover_fiction                       2610
# series_books                            2610
# trade_fiction_paperback                 2610
# paperback_nonfiction                    2606
# hardcover_nonfiction                    2605
# picture_books                           2595
# combined_print_and_e_book_nonfiction    2289
# combined_print_and_e_book_fiction       2164
# hardcover_graphic_books                 1850
# manga                                   1850
# mass_market_paperback                   1850
# paperback_graphic_books                 1850
# e_book_nonfiction                       1404
# e_book_fiction                          1404
# hardcover_political_books               1341
# young_adult_hardcover                   1135
# childrens_middle_grade_hardcover        1134
# food_and_fitness                         895
# paperback_advice                         865
# hardcover_advice                         849
# chapter_books                            770
# paperback_books                          769
# young_adult                              703
# childrens_middle_grade                   696
# travel                                   630
# animals                                  626
# humor                                    626
# religion_spirituality_and_faith          625
# family                                   618
# games_and_activities                     610
# fashion_manners_and_customs              610
# relationships                            606
# health                                   602
# education                                598
# culture                                  597
# celebrities                              596
# crime_and_punishment                     591
# combined_print_fiction                   590
# combined_print_nonfiction                587
# expeditions_disasters_and_adventures     561
# race_and_civil_rights                    556
# hardcover_business_books                 525
# paperback_business_books                 525
# espionage                                522
# indigenous_americans                     260
# audio_fiction                            203
# audio_nonfiction                         149
# graphic_books_and_manga                   65
# mass_market_monthly                       65
# Name: book_type, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y, random_state=1)

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
model = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
model.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7518216389077207

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[158,   0,   0, ...,   1,   0,   0],
#        [  0,  60,   0, ...,   0,   0,   0],
#        [  0,   0,  45, ...,   0,   0,   0],
#        ...,
#        [  4,   0,   0, ..., 115,   0,   0],
#        [  0,   0,   0, ...,   0, 156,   0],
#        [  0,   0,   0, ...,   0,   5, 236]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                                             pre       rec       spe        f1       geo       iba       sup
#
#                              animals       0.86      0.96      1.00      0.91      0.98      0.96       164
#                        audio_fiction       0.62      0.95      1.00      0.75      0.97      0.95        63
#                     audio_nonfiction       0.58      1.00      1.00      0.74      1.00      1.00        45
#                          celebrities       0.49      0.60      0.99      0.54      0.77      0.57       142
#                        chapter_books       0.46      0.93      0.98      0.62      0.96      0.91       197
#               childrens_middle_grade       0.38      0.91      0.98      0.54      0.94      0.89       167
#     childrens_middle_grade_hardcover       0.70      0.83      0.99      0.76      0.91      0.81       282
#    combined_print_and_e_book_fiction       0.22      0.29      0.96      0.25      0.53      0.26       546
# combined_print_and_e_book_nonfiction       0.47      0.17      0.99      0.25      0.42      0.16       566
#               combined_print_fiction       0.66      0.97      0.99      0.78      0.98      0.96       137
